# %% [markdown]
# #### Using BeautifulSoup to scrape the website for comments

# %%
import requests
from bs4 import BeautifulSoup
from fpdf import FPDF
import time

url = 'https://bglife.ru/topic/978/'
page = 1
all_comments = []

# 108
while page < 108:
    response = requests.get(f'{url}page/{page}/', verify=False)
    soup = BeautifulSoup(response.text, 'html.parser')
    articles = soup.find_all('article')

    for article in articles:
        # Extract author
        author_span = article.find('span', style='color:#1a8984')
        if author_span:
            author = author_span.text
        else:
            author = "Author not found"
        
        # Extract time
        time_element = article.find('time')
        if time_element:
            timestamp = time_element['datetime']
            time_text = time_element.text
        else:
            timestamp = "Timestamp not found"
            time_text = "Time text not found"
        
        # Extract message
        message_div = article.find('div', class_='ipsComment_main ipsType_large ipsType_richText ipsContained')
        if message_div:
            message = message_div.text.strip()
        else:
            message = "Message not found"

        print(f'Author: {author}')
        print(f'Time: {time_text} ({timestamp})')
        print(f'Message: {message}\n')
        
        
        all_comments.append({ 'message': message })

    print(f'Page {page} scraped!')

    page += 1
    
    # add a time delay to avoid getting blocked
    time.sleep(2) 

with open('comments.txt', 'w', encoding='utf-8') as f:
    for comment in all_comments:
        f.write(f"Username: {comment['username']}\n")
        f.write(f"Message: {comment['message']}\n")
        f.write('\n')
# Out:
# c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bglife.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Author: Evgeniy
# Time: 26 февраля 2012 (2012-02-26T19:00:12Z)
# Message: Я сдавал документы на получение гражданства в Софии. Уже вышел указ о предоставлении гражданства. Могу ли я получить личные документы в Москве или это нужно делать в Софии?
# И как это все происходит?
#
# Author: Author not found
# Time: 26 февраля 2012 (2012-02-26T19:14:23Z)
# Message: Я сдавал документы на получение гражданства в Софии. Уже вышел указ о предоставлении гражданства. Могу ли я получить личные документы в Москве или это нужно делать в Софии?
# И как это все происходит?
# Уже писали на этом форуме о том как это происходит.
# Получить личные документы в Москве не можете.
# Нужно приехать в Софию в Министерство правосудия по адресу ул. Аксаков, 5. Приемные дни ПН, ВТ, СР с 9-30 до 12.
# Там заполняете документ, что получили удостоверение о том что дали гражданство и получили оригиналы документов, которые находились в МП. Так же декларируете адрес регистрации в Болгарии. Получаете на руки удостоверение. Через две-три недели по месту регистрации в общине нужно подать заявление на адресную регистрацию и ЕГН (единый государственный номер). После того, как это получите, нужно идти в паспортный стол для подачи заявления на выдачу личных документов.
#
# Author: Author not found
# Time: 27 февраля 2012 (2012-02-27T21:22:27Z)
# Message: Здравствуйте.
# До получения указа, всё понятно. А вот для получения ЕГН надо иметь прописку или регистрацию, мне не совсем понятно, где, кого искать что бы зарегистрировали? Если можно, пожалуйста напишите пошагово, от получения указа до паспортного стола. Буду вам очень признательна
#
# Author: Tolik
# Time: 27 февраля 2012 (2012-02-27T21:28:40Z)
# Message: Здравствуйте.
# До получения указа, всё понятно. А вот для получения ЕГН надо иметь прописку или регистрацию, мне не совсем понятно, где, кого искать что бы зарегистрировали? Если можно, пожалуйста напишите пошагово, от получения указа до паспортного стола. Буду вам очень признательна
# При этом дети подают на гражданство по другой статье Закона о гражданстве, чл. 15. П. 3 (один из родителей гражданин Болгарии).
#
# Author: Author not found
# Time: 29 февраля 2012 (2012-02-29T18:14:07Z)
# Message: Спасибо за содержательные ответы. Но у меня есть личная карта, и адрес прописан София, Леге 6. (а посредник взял 250 евро за нормальную прописку, а я то не знала что это адрес общины, и я не одна такая ) Если я вас правильно поняла, то на данный момент мне надо удостоверение из общины. А дадут мне такое удостоверение если у меня, получается социальный адрес? Мне необходимо лично обратиться за удостоверением или можно по доверенности что бы за меня его получили?
#
# Author: Author not found
# Time: 29 февраля 2012 (2012-02-29T19:09:45Z)
# Message: Спасибо за содержательные ответы. Но у меня есть личная карта, и адрес прописан София, Леге 6. (а посредник взял 250 евро за нормальную прописку, а я то не знала что это адрес общины, и я не одна такая ) Если я вас правильно поняла, то на данный момент мне надо удостоверение из общины. А дадут мне такое удостоверение если у меня, получается социальный адрес? Мне необходимо лично обратиться за удостоверением или можно по доверенности что бы за меня его получили?
# Да, нужно "удостоверение за постоянен адрес". Если это София, то нужно получать вот здесь:
# sofia.bg/uslugi_new.asp?open=2
# Думаю что должны дать такое удостоверение. Речь идет о справке о постоянном адресе, который у Вас есть. А примут ли его в Министерстве правосудия, я не знаю. Должны принять. Это удостоверение формальность. Главное что у Вас есть гражданство.
# Получить удостоверение в общине можно по доверенности. Хотя это по срочному тарифу занимает один день. Можете и сами при подаче на гражданство детей. Это не сложно.
#
# Author: serg890
# Time: 1 марта 2012 (2012-03-01T14:39:35Z)
# Message: Всем привет вот в чем вопрос, у меня свидетельство о рождении Болгарское там же ЕГН я могу взять тур визу собрать тут документы приехать в Болгарию и там подать на гражданство? Очень нужно знать спасибо заранее
#
# Author: Author not found
# Time: 1 марта 2012 (2012-03-01T15:12:36Z)
# Message: Всем привет вот в чем вопрос, у меня свидетельство о рождении Болгарское там же ЕГН я могу взять тур визу собрать тут документы приехать в Болгарию и там подать на гражданство? Очень нужно знать спасибо заранее
# В другой ветке написал ответ на этот же вопрос.
# У Вас возможно есть гражданство. Это Вам нужно проверить. Если нет, то конечно можете подать.
#
# Author: Author not found
# Time: 4 марта 2012 (2012-03-04T22:13:09Z)
# Message: Всем привет, рада что попала на этот форум. У меня вопрос: в одном из ответов адрес Министерства правосудия указан - ул. Аксаков, 5, а у меня на талончике указан адрес ул. Славянска, 1. Это два разных ведомства, подскажите?
#
# Author: Author not found
# Time: 5 марта 2012 (2012-03-05T05:29:54Z)
# Message: Всем привет, рада что попала на этот форум. У меня вопрос: в одном из ответов адрес Министерства правосудия указан - ул. Аксаков, 5, а у меня на талончике указан адрес ул. Славянска, 1. Это два разных ведомства, подскажите?
# Одно и то же ведомство. Подача документов на гражданство на ул. Славянска, 1, получение удостоверения на ул. Аксаков, 5.
# Это рядом на параллельных улицах.
#
# Author: Author not found
# Time: 5 марта 2012 (2012-03-05T20:23:51Z)
# Message: Спасибо большое за ответ. Назрел следующий вопрос: можно ли по болгарскому паспорту (с пропиской в общине) купить автомобиль и зарегистрировать в Болгарии?
#
# Author: Tolik
# Time: 8 ноября 2012 (2012-11-08T20:33:19Z)
# Message: И можно ли ускорить получение паспорта?
# Я получил паспорта, международный и личную карту за 5 часов в Софии, при подаче спросили как я хочу оплатить срочно или нет, примерно 300 лев за оба и получение в течении 8 часов, но реально сделали за 5 часов.
#
# Author: Reactor
# Time: 8 ноября 2012 (2012-11-08T22:32:06Z)
# Message: Разве можно получить первый паспорт с картой за 8 часов? Вроде была информация, что первичное получение документов за 3 дня минимум. А поледующие можно и за 8 часов.
#
# Author: Tolik
# Time: 8 ноября 2012 (2012-11-08T23:02:29Z)
# Message: Разве можно получить первый паспорт с картой за 8 часов? Вроде была информация, что первичное получение документов за 3 дня минимум. А поледующие можно и за 8 часов.
# Если первично все сделали, получили регистрационную карту, код ЕГН, то поход в МВР и получение там паспорта возможно за 5 часов, я именно так и сделал. ЕГН делали 2 недели, регистрация 30 минут.
#
# Author: Author not found
# Time: 9 ноября 2012 (2012-11-09T06:07:49Z)
# Message: Разве можно получить первый паспорт с картой за 8 часов? Вроде была информация, что первичное получение документов за 3 дня минимум. А поледующие можно и за 8 часов.
# В Варне ожидание подтверждения из Министерства правосудия 10-14 дней. Регистрация, получение удостоверения о постоянном и настоящем адресе в общине 3 дня. Сразу же после этого можно подавать заявление на паспорт и личную карту. Срок 8 часов (один рабочий день), три дня и один месяц на выбор. За один день делают документы и тем, кто получает первый раз.
#
# Author: Evgeniy
# Time: 9 ноября 2012 (2012-11-09T13:07:42Z)
# Message: Andorf, Извиняюсь, за повтор, но все же. Получать удостоверение об адресе и ЕГН нужно там же где подавал заявление (т. Е. В общине)?
# И МВР - это полиция (паспортный стол)?
#
# Author: Author not found
# Time: 9 ноября 2012 (2012-11-09T15:45:32Z)
# Message: Andorf, Извиняюсь, за повтор, но все же. Получать удостоверение об адресе и ЕГН нужно там же где подавал заявление (т. Е. В общине)?
# И МВР - это полиция (паспортный стол)?
# Может быть я что то не понял.
# Если Вы подавали заявление на регистрацию как гражданин и заявление на постоянный и настоящий адрес в конкретной общине, то конечно в этой же общине нужно и получать удостоверения.
# А в Софии тоже так же?
# Не могу утверждать, что также в Софии. Но должно быть также, т. К. Сроки административных услуг во всех общинах одинаковый. В Варне так, как написал выше не из слухов, а личного участия в контроле получения подтверждения из МП в Общину Варна, подачу и получение по доверенности документов на регистрацию гражданина, постоянного и настоящего адреса, получение удостоверений и консультаций с паспортным столом о возможности получения личных документов в течение дня. Клиент подал заявление в паспортном столе примерно в 9-30, получил паспорт и личную карту в 16-00.
#
# Author: Reactor
# Time: 9 ноября 2012 (2012-11-09T18:34:18Z)
# Message: Я чего спрашиваю. Просто на соседнем форуме, который Вы тоже посещаете, утверждается в инструкции о действиях после получения указа, что первичное получение паспорта/карты возможно только минимум за 3-4 дня в Софии.
# Вот и хочется понять, на 1-2 дня ехать или на 4.
#
# Author: Tolik
# Time: 9 ноября 2012 (2012-11-09T18:57:41Z)
# Message: Я чего спрашиваю. Просто на соседнем форуме, который Вы тоже посещаете, утверждается в инструкции о действиях после получения указа, что первичное получение паспорта/карты возможно только минимум за 3-4 дня в Софии.
# Вот и хочется понять, на 1-2 дня ехать или на 4.
# Кстати я тоже это читал и думал что не возможно, но мне выдали паспорт в тот же день как подал документы, я все делал в Софии.
#
# Author: Author not found
# Time: 9 ноября 2012 (2012-11-09T19:15:15Z)
# Message: Я чего спрашиваю. Просто на соседнем форуме, который Вы тоже посещаете, утверждается в инструкции о действиях после получения указа, что первичное получение паспорта/карты возможно только минимум за 3-4 дня в Софии.
# Вот и хочется понять, на 1-2 дня ехать или на 4.
# Порядок первичного или вторичного получение документов никаким законным актом не регулируется. Возможно это требования служащих в окошке, возможно чья то практика. В Софии у меня практики нет, но "Толик" в сообщении выше говорит о том, что он получил документы в течение одного рабочего дня.
# Нет никаких оснований отказа от "експресна" услуга, т. Е. В течение одного рабочего дня.
# Спасибо, Вы ответили на мой вопрос. Но все же что такое МВР? Так, чтобы мне проще было
# МВР это Министерство на външните работи или по русски Министерство внутренних дел. В областных городах это называется МВР-Варна, МВР-Бургас и т. Д.
#
# Author: STEFANUA
# Time: 10 ноября 2012 (2012-11-10T11:03:48Z)
# Message: Tolik, здравствуйте! А если есть личная карта (ПМЖ), и соответственно: ЕГН и постоянный адрес в Варне, то можно ли при получении Указа о гражданстве, подавать заявление на документы (новую карту, загр. Паспорт) в Софии. Спасибо
#
# Author: Author not found
# Time: 10 ноября 2012 (2012-11-10T17:19:28Z)
# Message: Tolik, здравствуйте! А если есть личная карта (ПМЖ), и соответственно: ЕГН и постоянный адрес в Варне, то можно ли при получении Указа о гражданстве, подавать заявление на документы (новую карту, загр. Паспорт) в Софии. Спасибо
# Я не Толик, но немного знаю процедуру.
# Можно, если поменяете постоянный адрес с Варны на Софию с предъявлением личной карты с адресом в Софии.
# Т. К. У Вас ПМЖ, то при получении удостоверения в МП, а там об этом знают, то подтверждение о том, что дали гражданство, будет выслано по актуальному постоянному адресу, даже если Вы заявите другой.
#
# Author: STEFANUA
# Time: 10 ноября 2012 (2012-11-10T19:42:28Z)
# Message: Я не Толик, но немного знаю процедуру.
# Можно, если поменяете постоянный адрес с Варны на Софию с предъявлением личной карты с адресом в Софии.
# Т. К. У Вас ПМЖ, то при получении удостоверения в МП, а там об этом знают, то подтверждение о том, что дали гражданство, будет выслано по актуальному постоянному адресу, даже если Вы заявите другой.
# Когда подавались документы на гражданство, ПМЖ еще не было, поэтому пост. Адрес не знают. Возможно Указ будут вручать в Софии. Я почему спрашиваю, ведь документы с Варны везут в Софию и там изготавливают лич. Карту и загр. Паспорт, потом везут обратно, это так долго. Меньше десяти дней не получится.
#
# Author: Author not found
# Time: 10 ноября 2012 (2012-11-10T19:58:20Z)
# Message: Когда подавались документы на гражданство, ПМЖ еще не было, поэтому пост. Адрес не знают. Возможно Указ будут вручать в Софии. Я почему спрашиваю, ведь документы с Варны везут в Софию и там изготавливают лич. Карту и загр. Паспорт, потом везут обратно, это так долго. Меньше десяти дней не получится.
# 2. Требуют ли двух болгар-свидетелей? Указ мой ноябрьский.
#
# Author: Author not found
# Time: 6 декабря 2012 (2012-12-06T13:56:27Z)
# Message: Конкретный вопрос по получению первичного паспорта на Мария Луиза в Софии:
# 1. Берут ли документы на 8-часовой сервис у тех кто впервые получает паспорт? ЕГН давно оформлен, данные в базе полиции есть.
# 2. Требуют ли двух болгар-свидетелей? Указ мой ноябрьский.
# Да, это возможно и в этой же ветке писали об этом:
# bglife.ru/threads/4269/page-3#post-232875
#
# Author: Author not found
# Time: 6 декабря 2012 (2012-12-06T17:39:48Z)
# Message: Да, это возможно и в этой же ветке писали об этом:
# bglife.ru/threads/4269/page-3#post-232875
# Я конечно же это видел  Хочу убедиться что больной был в том же исходном состоянии... С указом и свежим ЕГН. Слухи ходят что у таких просят двух свидетелей и делают 3 дня.
#
# Author: Author not found
# Time: 6 декабря 2012 (2012-12-06T18:36:29Z)
# Message: Я конечно же это видел  Хочу убедиться что больной был в том же исходном состоянии... С указом и свежим ЕГН. Слухи ходят что у таких просят двух свидетелей и делают 3 дня.
# Насколько я знаю, то "больной" был в том же исходном состоянии и именно на бул. М. Луиза все сделал за один день без свидетелей. Так же мне не известны законодательные меры, что бы вообще требовались свидетели. Возможно в столице так бывает, возможно кто то это выдумывает. Могу сказать практику в г. Варна. За последний месяц я лично сопровождал двух клиентов по регистрации, как гражданина с присвоением ЕГН, получение постоянного адреса и получению паспортов и личных карт. Один клиент сделал все за один день, второй за три по финансовым соображениям и срочности. Никаких свидетелей не просили.
#
# Author: demirov
# Time: 16 января 2013 (2013-01-16T08:11:43Z)
# Message: Добрый день!
# На днях проверяя свой номер, прочитал:Молбата Ви е уважена.
# Вашата преписка е включена в Указ 147 от 2012 година
# Перечитал всю ветку (вроде не сильно большая), спасибо большое всем консультантам. Но все равно осталось несколько вопросов.если указывать адрес социальной прописки (г. София, ул. Леге 6):какие ограничения у гражданина Болгарии?Также есть необходимость ждать 2-3 недели для получения удостоверения о прописке и ЕГН?
# 2. Какова стоимость получения личной карты и загран. Паспорта, если ждать 3дня (я так понял личная карта 1день - 300лев=200у. Е. США)
#
# Author: Author not found
# Time: 16 января 2013 (2013-01-16T08:51:01Z)
# Message: Добрый день!
# На днях проверяя свой номер, прочитал:
# Перечитал всю ветку (вроде не сильно большая), спасибо большое всем консультантам. Но все равно осталось несколько вопросов.если указывать адрес социальной прописки (г. София, ул. Леге 6):какие ограничения у гражданина Болгарии?Также есть необходимость ждать 2-3 недели для получения удостоверения о прописке и ЕГН?
# 2. Какова стоимость получения личной карты и загран. Паспорта, если ждать 3дня (я так понял личная карта 1день - 300лев=200у. Е. США)
# Ограничений никаких нет. Единственное, не сможете оформлять ВНЖ супруге, т. К. Нужно доказывать наличие жилья.
# Из МП в общины подтверждения о даче гражданство поступают через 10-14 дней. До этого не возможно подать заявление на постоянный адрес и ЕГН. Удостоверения делаются в течение 3-4 дней.
# Если три дня, то карта 36 лев, паспорт 80 лев. Если один день, то карта 90 лев, паспорт 200 лев.
#
# Author: demirov
# Time: 16 января 2013 (2013-01-16T13:45:13Z)
# Message: Просто где-то читал, что нельзя отправлять приглашения родственникам, оформлять автомобили - синие номера,... Хотелось бы узнать какие еще ограничения, вдруг там есть что-то важное, может где-то расписано?
# Тогда еще вопрос, я должен взять удостоверение из МП лично, остальные процедуры я могу дать кому-либо доверенность, чтобы они оформили все документы (и личну карту, и загран. Паспорт), верно? Или я все документы должен забирать/подавать лично? Нотариусы в курсе, какую доверенность необходимо выписать?
#
# Author: Author not found
# Time: 16 января 2013 (2013-01-16T14:27:53Z)
# Message: Просто где-то читал, что нельзя отправлять приглашения родственникам, оформлять автомобили - синие номера,... Хотелось бы узнать какие еще ограничения, вдруг там есть что-то важное, может где-то расписано?
# Тогда еще вопрос, я должен взять удостоверение из МП лично, остальные процедуры я могу дать кому-либо доверенность, чтобы они оформили все документы (и личну карту, и загран. Паспорт), верно? Или я все документы должен забирать/подавать лично? Нотариусы в курсе, какую доверенность необходимо выписать?
# С этим адресом нельзя все то, где нужно показывать где Вы собственно живете в Болгарии. Вы правы, авто не зарегистрируют. Синие номера здесь вообще не причем, Вы же не иностранец. Нельзя сделать приглашение родственникам.
# Если не собираетесь здесь жить какое то время, то этой прописки достаточно. Когда решите жить в Болгарии, то новая прописка делается три дня в любой общине плюс нужна замена карты.
# Получать удостоверение о гражданстве можно только лично. Доверенное лицо, и такая услуга существует, проследит поступление подтверждения из МП в общину, подаст документы и получит удостоверение о постоянном адресе, выяснит в паспортной службе занесены ли Вы в реестр граждан РБ и дает отмашку на второй приезд для подачи заявления на личные документы.
# Нотариусы знают какую доверенность нужно.
#
# Author: demirov
# Time: 16 января 2013 (2013-01-16T14:58:10Z)
# Message: Т. Е. В любом случае необходимо два раза приезжать?
# Я просто думал, что если социальный адрес (г. София, ул. Леге 6), то может процедура быстрее проходит или по другой схеме, более упрощенной? Так как основной срок - поступление подтверждения из МП в общину
#
# Author: Author not found
# Time: 16 января 2013 (2013-01-16T15:05:13Z)
# Message: Т. Е. В любом случае необходимо два раза приезжать?
# Я просто думал, что если социальный адрес (г. София, ул. Леге 6), то может процедура быстрее проходит или по другой схеме, более упрощенной? Так как основной срок - поступление подтверждения из МП в общину
# Нет упрощенной процедуры. Документы из МП приходят что в Варну, что через два квартала в Софии примерно через 7-14 дней. А процедура получения удостоверения о постоянном адресе и личных документов везде одинакова.
# Да, два раза приезжать или один, но дней так на 20-30.
#
# Author: Reactor
# Time: 17 января 2013 (2013-01-17T06:08:42Z)
# Message: По квитанциям и таксам вопрос.
# За выдачу удостоверения в министерстве надо оплатить в банке 50 лев.
# А при подаче заявления в общину на Леге 6 для адресной регистрации и внесения в базу, какие-то квитанции надо оплачивать?
# И дальше для полиции только оплатить 200 + 90 лев за экспресс изготовление карты и паспорта?
#
# Author: Author not found
# Time: 17 января 2013 (2013-01-17T06:31:16Z)
# Message: По квитанциям и таксам вопрос.
# За выдачу удостоверения в министерстве надо оплатить в банке 50 лев.
# А при подаче заявления в общину на Леге 6 для адресной регистрации и внесения в базу, какие-то квитанции надо оплачивать?
# И дальше для полиции только оплатить 200 + 90 лев за экспресс изготовление карты и паспорта?
# В общине платится около 25 лев за все.
# ...
#
# Author: Esska
# Time: 2 мая 2017 (2017-05-02T13:40:12Z)
# Message: Смайлы ваши не сильно разделяю, а за остальные подсказки - большое спасибо!
# А какую именно справку из МВР для НАПа требуют подскажите пожалуйста, если знаете.
#
# Author: Lena Gor
# Time: 3 мая 2017 (2017-05-03T20:49:50Z)
# Message: Цитирую:
# Удостоверение за влизане и излизане от страната - от Главна Дирекция Гранична полиция на МВР
#
# Author: Esska
# Time: 4 мая 2017 (2017-05-04T09:14:36Z)
# Message: Цитирую:
# Удостоверение за влизане и излизане от страната - от Главна Дирекция Гранична полиция на МВР
# Благодарю.
#
# Author: Acidkiller
# Time: 5 мая 2017 (2017-05-05T08:26:16Z)
# Message: Подскажите, а сколько обычно ждать выхода номера указа, у меня статус "Предстои издаването на указ на Вицепрезидента" уже висит с февраля месяца
# Спасибо
#
# Author: Harita
# Time: 5 мая 2017 (2017-05-05T08:37:52Z)
# Message: @Acidkiller, на моей памяти максимум 3.5 месяца люди ждали.
# Но это не значит, что не может быть нового рекорда по срокам :-)
# У знакомой тоже этот статус висит с 5-6 февраля
#
# Author: Lena Gor
# Time: 7 мая 2017 (2017-05-07T22:45:20Z)
# Message: Благодарю.
# Если у вас какие новости будут по этой теме, напишите, пожалуйста, в личку... Вопрос так и остался для меня открытым...
# И что-то мне подсказывает, что не так просто это удостоверение МВР получить, наверняка скажут, надо было приходить по приезду и отмечаться у нас...
# Так что, пишите, если что новое узнаете...
#
# Author: Harita
# Time: 8 мая 2017 (2017-05-08T08:34:54Z)
# Message: @Lena Gor, отмечаться не надо, в Миграции есть данные о пересечениях границы, т. к. при получении/ продлении ПМЖ смотрят сроки отсутствия в Болгарии
#
# Page 34 scraped!
# c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'bglife.ru'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Author: OgiSrb
# Time: 8 мая 2017 (2017-05-08T16:21:38Z)
# Message: Как долго после собеседования статус изменится на: "Предстои издаването на указ на Вицепрезидента" ? Спасибо!
#
# Author: ap2002ua
# Time: 8 мая 2017 (2017-05-08T16:23:08Z)
# Message: Как долго после собеседования статус изменится на: "Предстои издаването на указ на Вицепрезидента" ? Спасибо!
# Неизвестно. Я жду с ноября 2015...
#
# Author: OgiSrb
# Time: 8 мая 2017 (2017-05-08T16:27:56Z)
# Message: Неизвестно. Я жду с ноября 2015...
# Получали ли вы какую-либо информацию о том, что в ваших документах что-то не так? Ожидание с ноября 2015 года не кажется правильным.
# Я удивляюсь, почему люди обращаются с адвокатом только через несколько месяцев (так мне сказали несколько иммиграционных адвокатов)
#
# Author: ap2002ua
# Time: 8 мая 2017 (2017-05-08T17:06:23Z)
# Message: Получали ли вы какую-либо информацию о том, что в ваших документах что-то не так? Ожидание с ноября 2015 года не кажется правильным.
# Я удивляюсь, почему люди обращаются с адвокатом только через несколько месяцев (так мне сказали несколько иммиграционных адвокатов)
# Информации - никакой. Написано:
# Образувана преписка N:53**/20**/27.07.2016 г. Преписката се намира в процедура по задължително съгласуване.
# Все. Так весит с момента собеседования. Ничего нового, типа ждем такие то документы, нет.
# С ноябрем, 2015 - это я не собеседование прошел, а подавал документы на запись на собеседование. Не точно сказал раньше.
# Уже давно писано-переписано о том, что идут задержки и народ ждет указа больше года, и больше полутора лет. Добавим сюда выборы президента. На счет обращения с адвокатом - не понял. Короче говоря, т. К. Мне не горит, то я особо и не напрягаюсь.
#
# Author: Esska
# Time: 11 мая 2017 (2017-05-11T07:03:50Z)
# Message: Если у вас какие новости будут по этой теме, напишите, пожалуйста, в личку... Вопрос так и остался для меня открытым...
# И что-то мне подсказывает, что не так просто это удостоверение МВР получить, наверняка скажут, надо было приходить по приезду и отмечаться у нас...
# Так что, пишите, если что новое узнаете...
# Мы едем за указом 12 июня. Посещение НАП тоже планируем исходя из той информации, что почерпнули здесь. Пока вооружилась законами. Там посмотрим на месте. Отпишусь тут потом
#
# Author: Eftimovich
# Time: 11 мая 2017 (2017-05-11T08:30:04Z)
# Message: @Esska, когда приедете в НАП покажите им выписки из закона и скрин с их сайта от что нужно подать декларацию о том что не живёте в Болгарии постоянно (других документов там не указано). А если потребуют что либо, кроме декларации, тогда первым делом попросите чтобы они вам предоставили основание на котором они требуют эти документы, конкретные законы или наредбы! Можно ещё к начальнику ходить на консультацию!
#
# Author: Lena Gor
# Time: 12 мая 2017 (2017-05-12T06:43:17Z)
# Message: @Lena Gor, отмечаться не надо, в Миграции есть данные о пересечениях границы, т. к. при получении/ продлении ПМЖ смотрят сроки отсутствия в Болгарии
# Да у меня гражданство уже, думаете тоже отмечают, когда я въезжаю-выезжаю?
# Когда я прошлый раз приезжала, паспорт даже не прокатали на погранпосте, просто посмотрели и отдали, и так же при выезде
# Не знаю даже, как они отслеживают моё пребывание на территории РБ
# Мы едем за указом 12 июня. Посещение НАП тоже планируем исходя из той информации, что почерпнули здесь. Пока вооружилась законами. Там посмотрим на месте. Отпишусь тут потом
# У вас немножко другая история...
# Я вовремя не узнала, что надо идти в НАП, чтоб отписаться
# А вы это можете сделать вовремя, как только получите регистрацию, и в этот момент вам не надо доказывать, что вы не живёте на территории РБ
# У вас получается нет этого временного промежутка после регистрации, если, конечно, вы сразу пойдете в НАП
# Ну всё равно напишите, что вам скажут
#
# Author: simfira
# Time: 31 мая 2017 (2017-05-31T15:34:50Z)
# Message: Добрый день. Вот не знаю, где спросить, т направьте, если что.
# С паспортом гражанина Болгарии как в Европу выезжать? Загран делать или это единый будет паспорт? (Указ вышел, Будем летом делать паспорт).
# Если загран, то куда обращаться? Может стоимость-сроки скажете.
# Спасибо.
#
# Author: Ukrainka
# Time: 31 мая 2017 (2017-05-31T16:07:48Z)
# Message: Добрый день. Вот не знаю, где спросить, т направьте, если что.
# С паспортом гражанина Болгарии как в Европу выезжать? Загран делать или это единый будет паспорт? (Указ вышел, Будем летом делать паспорт).
# Если загран, то куда обращаться? Может стоимость-сроки скажете.
# Спасибо.
# После выхода Указа и получения удостоверения о болгарском гражданстве вы должы получить документ, удостоверяющий личность - личная карточка.
# По этому документу и будете ездить в Европу. Есть возможность получить и международный паспорт.
# Стоимость и сроки выбираете сами. Есть экспресс-услуга получения документов - за 1 день (312 лв. За оба документа), срочная за 3 рабочих дня (125 лв.) и обыкновенная за 30 дней (61 лв.)
#
# Author: Computec
# Time: 31 мая 2017 (2017-05-31T20:00:15Z)
# Message: Доброго дня, на сайте уже почти год висит
# Вашето удостоверение е изпратено в консулска служба Одеса-Украйна. При получаване на удостоверението следва да заявите адрес за регистрация в Република България, както и да представите 2 бр. актуални снимки паспортен формат.
# Хотя через консульство в Одессе эти документы уехали в июле 2016 (с регистрацией на Леге 6)
# Есть ли смысл ехать в Софию до того как измениться статус или дальнейших изменений в статусе можно не ожидать?
#
# Author: Author not found
# Time: 1 июня 2017 (2017-06-01T14:33:10Z)
# Message: Доброго дня, на сайте уже почти год висит
# Хотя через консульство в Одессе эти документы уехали в июле 2016 (с регистрацией на Леге 6)
# Есть ли смысл ехать в Софию до того как измениться статус или дальнейших изменений в статусе можно не ожидать?
# Министерство правосудия уже попрощалось с Вами и никаких далее изменений в записи не будет. Дальше Вам нужно ехать в Софию и заниматься пропиской и личными документами. А вот дошло ли Ваше заявление до МП и далее до общины можно узнать в общине только лично или по доверенности.
#
# Author: Валер
# Time: 3 июня 2017 (2017-06-03T21:35:15Z)
# Message: Добрый день. Вот не знаю, где спросить, т направьте, если что.
# С паспортом гражанина Болгарии как в Европу выезжать? Загран делать или это единый будет паспорт? (Указ вышел, Будем летом делать паспорт).
# Если загран, то куда обращаться? Может стоимость-сроки скажете.
# Спасибо.
# Везде с карточкой езжу, загран нужен только не в страны ЕС, даже в норвегию можете, хоть она не в ЕС Не заморачивайтесь везде все зависит от погранцов, а они толерантны к гражданам ЕС, время такое
#
# Author: anderson99
# Time: 5 июня 2017 (2017-06-05T19:24:40Z)
# Message: Доброго дня, на сайте уже почти год висит
# Хотя через консульство в Одессе эти документы уехали в июле 2016 (с регистрацией на Леге 6)
# Есть ли смысл ехать в Софию до того как измениться статус или дальнейших изменений в статусе можно не ожидать?
# Так Вы своё удостоверение (указ) уже получили? Как появился этот статус на сайте МП через сколько времени пришло ваше удостоверение в консульство в Одессу?
#
# Author: ReyOK
# Time: 6 июня 2017 (2017-06-06T10:04:39Z)
# Message: Везде с карточкой езжу, загран нужен только не в страны ЕС, даже в норвегию можете, хоть она не в ЕС Не заморачивайтесь везде все зависит от погранцов, а они толерантны к гражданам ЕС, время такое
# На внешних границах ЕС нужен паспорт.
#
# Author: Нота ля
# Time: 8 июня 2017 (2017-06-08T13:41:00Z)
# Message: Может кто-то подскажет, какие номера получают сейчас указ? У нас собеседование было в конце апреля 2016. Заранее спасибо))
#
# Author: Lana0703
# Time: 9 июня 2017 (2017-06-09T06:30:59Z)
# Message: Может кто-то подскажет, какие номера получают сейчас указ? У нас собеседование было в конце апреля 2016. Заранее спасибо))
# https://docs.google.com/spreadsheets/d/1_JbXqJiKaJq-tuNMf9chQ4KtoJNScnffF1I35O8xflE/edit#gid=0
# Можете посмотреть информацию и себя внести
#
# Author: Eftimovich
# Time: 9 июня 2017 (2017-06-09T09:51:01Z)
# Message: Сегодня изменился статус на финален! На конец-то! Собеседование в сентябре 2016
#
# Author: Lana0703
# Time: 9 июня 2017 (2017-06-09T12:31:37Z)
# Message: Сегодня изменился статус на финален! На конец-то! Собеседование в сентябре 2016
#
# Author: serbin_u_v
# Time: 9 июня 2017 (2017-06-09T19:40:09Z)
# Message: Сегодня изменился статус на финален! На конец-то! Собеседование в сентябре 2016
# Так вносите быстрее результат в таблицу))
# Неужели заработали? Мне уже казалась эта таблица остановилась мертво. А сейчас смотрю, тоже мой номерок 30 подходит. Может к 1 августа на день рождения подарок будет?)))
#
# Author: Eftimovich
# Time: 9 июня 2017 (2017-06-09T20:02:59Z)
# Message: Уже давно внёс
# @serbin_u_v, вы сами то себя внесли?
#
# Author: serbin_u_v
# Time: 10 июня 2017 (2017-06-10T13:32:06Z)
# Message: @serbin_u_v, вы сами то себя внесли?
# Написано выше, я 30
# Уже давно внёс
# Извиняюсь, не заметил сразу. Вы вроде 26 . Я и на форуме раньше Вас зарегистрировался))) А где остальные тысячи человек которые получают гражданство?
#
# Author: Eftimovich
# Time: 10 июня 2017 (2017-06-10T13:43:51Z)
# Message: Так вы под другим ником в таблице
# Извиняюсь, не заметил сразу. Вы вроде 26 . Я и на форуме раньше Вас зарегистрировался))) А где остальные тысячи человек которые получают гражданство?
# Так не все кто получает гражданство зарегистрированы на форуме!
#
# Author: serbin_u_v
# Time: 10 июня 2017 (2017-06-10T14:19:20Z)
# Message: Так не все кто получает гражданство зарегистрированы на форуме!
# Я в курсе.)))
# Формулу в таблице Вам подкоретировал, теперь все гуд.
# Пока отставание по сроками на 2-3 месяца, будем ждать.
#
# Author: Esska
# Time: 12 июня 2017 (2017-06-12T20:46:23Z)
# Message: Всем доброй ночи.
# Начинаю наш квест: получение болгарского паспорта)
# Муж сегодня приехал в министерство получать указ. В указанное время его вызвали, отдали указ и документы по списку.
# Внимание! Копию свидетельства о рождении с переводом и легализацией не отдали. И никакие "моля моля, сделайте себе копию" не помогли. Нет и все. Пошел сразу в бюро переводов, в котором делал это ранее. Забирать завтра после обеда. В общине на Леге 6 доки приняли и отправили на 10 дней... Дальше "моля, у меня самолет"... Я промолчу тут как это вышло... Вообщем сказали забирать завтра... (Кому очень надо напишу в личку). Завтра продолжение квеста...
#
# Author: Нота ля
# Time: 13 июня 2017 (2017-06-13T10:21:50Z)
# Message: Помогите внести себя в таблицу, плит из:-)не получается и всё
# Я в курсе.)))
# Формулу в таблице Вам подкоретировал, теперь все гуд.
# Пока отставание по сроками на 2-3 месяца, будем ждать.
#
# Author: serbin_u_v
# Time: 14 июня 2017 (2017-06-14T05:35:07Z)
# Message: Помогите внести себя в таблицу, плит изне получается и всё
# В чем помощь нужна? Пишите в личку, если умеете)
#
# Author: Esska
# Time: 14 июня 2017 (2017-06-14T16:24:35Z)
# Message: Продолжение. Пошли по стандартному пути всех форумчан. Указ забрали в понедельник утром, паспорт и ЛК в среду в 16.00. Одна печалька только с агенством по доходам. В среду пытались атаковать дважды, но у них не работала программа, поэтому будем пытаться завтра утром. Если нет, то этот пункт пропустим. Из за этого сидеть в Софии - у нас путевка на море идет). Тогда в другой раз уже. Всем поделившимся информацией - огромное спасибо.
# PS Ценники те же, что и раньше, паспорт 305 лев по экспресс. И накидывайте сверху еще 100 лев на доп расходы...
# Кстати, копию СР с переводом и легализацией не брали. Зря делали
# Цитирую:
# Удостоверение за влизане и излизане от страната - от Главна Дирекция Гранична полиция на МВР
# Добрый день, вы были правы. Нам в НАПе все тоже самое сказали. Список видимо тот же. Не имеет значение, когда выдан паспорт.
# За нас написали какое-то очень длинное заявление. Мы спросили, так платить не надо будет) Сказали надо) Но дали эту бумагу. Т. Е. Потом надо будет доказывать, что ты тут не жил.
#
# Author: Eftimovich
# Time: 16 июня 2017 (2017-06-16T05:42:07Z)
# Message: @Esska, нужно было спросить на каком основании требуют эти документы? Пусть закон покажут!!! Вот например что написано в законе ЗЗО
# Чл. 40в. (Нов - ДВ, бр. 23 от 2013 г., в сила от 8.03.2013 г.) Българските граждани, които са граждани и на друга държава и живеят в чужбина повече от 183 дни през една календарна година, могат да декларират, че не дължат здравноосигурителни вноски, като подадат в Националната
# Чётко написано если гражданин БГ является гражданином другой страны то может подать декларацию!!!
#
# Author: Esska
# Time: 16 июня 2017 (2017-06-16T06:08:00Z)
# Message: @Esska, нужно было спросить на каком основании требуют эти документы? Пусть закон покажут!!! Вот например что написано в законе ЗЗО
# Чл. 40в. (Нов - ДВ, бр. 23 от 2013 г., в сила от 8.03.2013 г.) Българските граждани, които са граждани и на друга държава и живеят в чужбина повече от 183 дни през една календарна година, могат да декларират, че не дължат здравноосигурителни вноски, като подадат в Националната
# Чётко написано если гражданин БГ является гражданином другой страны то может подать декларацию!!!
# И Вы правы, и все я это знаю. Но муж ни слова не знает по болгарски, а с русским там знатоков не было. Сложно что то доказывать на пальцах. Туда в данном случае нужно идти четко с человеком, который знает болгарский, либо вот так. В любом случае я не думаю, что это проблема мирового масштаба потом в последствии доказать, что тебя тут не было. Но декларацию я всеравно им заказным письмом вышлю
#
# Author: Vlad888
# Time: 21 июня 2017 (2017-06-21T10:28:42Z)
# Message: Добрый день, уважаемые форумчане！подскажите.
# Собираюсь ехать за указом, но перед этим я поменял загран паспорт на биометрический,（поменялся номер）не будет ли у меня проблем при оформлении болгарских документов. Спасибо.
#
# Page 35 scraped!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 52
#      49     page += 1
#      51     # add a time delay to avoid getting blocked
# ---> 52     time.sleep(2)
#      54 with open('comments.txt', 'w', encoding='utf-8') as f:
#      55     for comment in all_comments:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Uploading the data to a GPT model

# %%
from dotenv import load_dotenv
from PyPDF2 import PdfReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import ElasticVectorSearch, Pinecone, Weaviate, FAISS
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI
import os

# load the kays
load_dotenv("keys.env")

# access the keys
openai_api_key = os.environ.get("OPENAI_API_KEY")

# Set environment variables
os.environ["OPENAI_API_KEY"] = openai_api_key

# %%
# location of the pdf file/files. 
reader = PdfReader('part2.pdf')

# %%
# read data from the file and put them into a variable called raw_text
raw_text = ''
for i, page in enumerate(reader.pages):
    text = page.extract_text()
    if text:
        raw_text += text
        
# We need to split the text that we read into smaller chunks so that during information retreival we don't hit the token size limits. 

text_splitter = CharacterTextSplitter(        
    separator = "\n",
    chunk_size = 1000,
    chunk_overlap  = 200,
    length_function = len,
)
texts = text_splitter.split_text(raw_text)

# Print the second chunk and the total number of chunks to check if the text has been properly split
print("Total number of chunks:", len(texts))
print()

# Print information about the uploaded PDF
print("=== PDF Information ===")
print("File name:", "file.pdf")
print("Number of pages:", len(reader.pages))
print("PDF metadata:")
for key, value in reader.metadata.items():
    print(f"{key}: {value}")
print("======================")
# Out:
# Total number of chunks: 934
#
# === PDF Information ===
# File name: file.pdf
# Number of pages: 221
# PDF metadata:
# /Creator: Writer
# /Producer: LibreOffice 7.4
# /CreationDate: D:20230413082933+02'00'
# ======================

# %%
# Download embeddings from OpenAI
# Initialize the OpenAIEmbeddings class, which is responsible for converting texts into embeddings
embeddings = OpenAIEmbeddings()

# Create a FAISS index from the texts using the downloaded embeddings
# The FAISS index allows for efficient similarity search in high dimensional space (e.g., searching for similar text chunks)
docsearch = FAISS.from_texts(texts, embeddings)

# Load a question-answering (QA) chain
# The QA chain is a sequence of models or components that work together to answer questions based on the input text
# The "stuff" chain type could be a specific sequence of models designed for answering questions on a particular domain or dataset
chain = load_qa_chain(OpenAI(), chain_type="stuff")

# %% [markdown]
# #### Asking questions to the model

# %%
# Define the query you want to ask
query = "Какая последовательность действий для получения пасспорта после выхода в приказ?"

# Perform a similarity search using the FAISS index to find relevant documents from the 'texts' variable
# This returns a list of documents (text chunks) that are most similar to the input query
docs = docsearch.similarity_search(query)

# %%
# Run the question-answering (QA) chain on the relevant documents and the input query
# This will generate an answer to the query based on the information in the 'docs' variable
answer = chain.run(input_documents=docs, question=query)

def divide_into_paragraphs(text, max_length):
    words = text.split()
    paragraphs = []
    current_paragraph = ""

    for word in words:
        if len(current_paragraph) + len(word) + 1 > max_length:
            paragraphs.append(current_paragraph.strip())
            current_paragraph = ""

        current_paragraph += f" {word}"

    if current_paragraph.strip():
        paragraphs.append(current_paragraph.strip())

    return paragraphs

# Divide the answer into paragraphs after around 90 characters
formatted_answer = divide_into_paragraphs(answer, 90)

# Print the query, relevant documents, and the formatted answer
print("=== Query ===")
print(query)
print()

print("=== Relevant Documents ===")
for i, doc in enumerate(docs, start=1):
    print(f"Document {i}:")
    print(doc)
    print()

print("=== Answer ===")
for i, paragraph in enumerate(formatted_answer, start=1):
    print(paragraph)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[83], line 3
#       1 # Run the question-answering (QA) chain on the relevant documents and the input query
#       2 # This will generate an answer to the query based on the information in the 'docs' variable
# ----> 3 answer = chain.run(input_documents=docs, question=query)
#       5 def divide_into_paragraphs(text, max_length):
#       6     words = text.split()
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:216, in Chain.run(self, *args, **kwargs)
#     213     return self(args[0])[self.output_keys[0]]
#     215 if kwargs and not args:
# --> 216     return self(kwargs)[self.output_keys[0]]
#     218 raise ValueError(
#     219     f"`run` supported with either positional arguments or keyword arguments"
#     220     f" but not both. Got args: {args} and kwargs: {kwargs}."
#     221 )
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:116, in Chain.__call__(self, inputs, return_only_outputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
# --> 116     raise e
#     117 self.callback_manager.on_chain_end(outputs, verbose=self.verbose)
#     118 return self.prep_outputs(inputs, outputs, return_only_outputs)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:113, in Chain.__call__(self, inputs, return_only_outputs)
#     107 self.callback_manager.on_chain_start(
#     108     {"name": self.__class__.__name__},
#     109     inputs,
#     110     verbose=self.verbose,
#     111 )
#     112 try:
# --> 113     outputs = self._call(inputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\combine_documents\base.py:56, in BaseCombineDocumentsChain._call(self, inputs)
#      54 # Other keys are assumed to be needed for LLM prediction
#      55 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# ---> 56 output, extra_return_dict = self.combine_docs(docs, **other_keys)
#      57 extra_return_dict[self.output_key] = output
#      58 return extra_return_dict
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\combine_documents\stuff.py:89, in StuffDocumentsChain.combine_docs(self, docs, **kwargs)
#      87 inputs = self._get_inputs(docs, **kwargs)
#      88 # Call predict on the LLM.
# ---> 89 return self.llm_chain.predict(**inputs), {}
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\llm.py:151, in LLMChain.predict(self, **kwargs)
#     137 def predict(self, **kwargs: Any) -> str:
#     138     """Format prompt with kwargs and pass to LLM.
#     139
#     140     Args:
#    (...)
#     149             completion = llm.predict(adjective="funny")
#     150     """
# --> 151     return self(kwargs)[self.output_key]
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:116, in Chain.__call__(self, inputs, return_only_outputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
# --> 116     raise e
#     117 self.callback_manager.on_chain_end(outputs, verbose=self.verbose)
#     118 return self.prep_outputs(inputs, outputs, return_only_outputs)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:113, in Chain.__call__(self, inputs, return_only_outputs)
#     107 self.callback_manager.on_chain_start(
#     108     {"name": self.__class__.__name__},
#     109     inputs,
#     110     verbose=self.verbose,
#     111 )
#     112 try:
# --> 113     outputs = self._call(inputs)
#     114 except (KeyboardInterrupt, Exception) as e:
#     115     self.callback_manager.on_chain_error(e, verbose=self.verbose)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\llm.py:57, in LLMChain._call(self, inputs)
#      56 def _call(self, inputs: Dict[str, Any]) -> Dict[str, str]:
# ---> 57     return self.apply([inputs])[0]
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\llm.py:118, in LLMChain.apply(self, input_list)
#     116 def apply(self, input_list: List[Dict[str, Any]]) -> List[Dict[str, str]]:
#     117     """Utilize the LLM generate method for speed gains."""
# --> 118     response = self.generate(input_list)
#     119     return self.create_outputs(response)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\llm.py:62, in LLMChain.generate(self, input_list)
#      60 """Generate LLM result from inputs."""
#      61 prompts, stop = self.prep_prompts(input_list)
# ---> 62 return self.llm.generate_prompt(prompts, stop)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\llms\base.py:107, in BaseLLM.generate_prompt(self, prompts, stop)
#     103 def generate_prompt(
#     104     self, prompts: List[PromptValue], stop: Optional[List[str]] = None
#     105 ) -> LLMResult:
#     106     prompt_strings = [p.to_string() for p in prompts]
# --> 107     return self.generate(prompt_strings, stop=stop)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\llms\base.py:140, in BaseLLM.generate(self, prompts, stop)
#     138 except (KeyboardInterrupt, Exception) as e:
#     139     self.callback_manager.on_llm_error(e, verbose=self.verbose)
# --> 140     raise e
#     141 self.callback_manager.on_llm_end(output, verbose=self.verbose)
#     142 return output
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\llms\base.py:137, in BaseLLM.generate(self, prompts, stop)
#     133 self.callback_manager.on_llm_start(
#     134     {"name": self.__class__.__name__}, prompts, verbose=self.verbose
#     135 )
#     136 try:
# --> 137     output = self._generate(prompts, stop=stop)
#     138 except (KeyboardInterrupt, Exception) as e:
#     139     self.callback_manager.on_llm_error(e, verbose=self.verbose)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\llms\openai.py:292, in BaseOpenAI._generate(self, prompts, stop)
#     290     choices.extend(response["choices"])
#     291 else:
# --> 292     response = completion_with_retry(self, prompt=_prompts, **params)
#     293     choices.extend(response["choices"])
#     294 if not self.streaming:
#     295     # Can't update token usage if streaming
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\llms\openai.py:99, in completion_with_retry(llm, **kwargs)
#      95 @retry_decorator
#      96 def _completion_with_retry(**kwargs: Any) -> Any:
#      97     return llm.client.create(**kwargs)
# ---> 99 return _completion_with_retry(**kwargs)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\llms\openai.py:97, in completion_with_retry.<locals>._completion_with_retry(**kwargs)
#      95 @retry_decorator
#      96 def _completion_with_retry(**kwargs: Any) -> Any:
# ---> 97     return llm.client.create(**kwargs)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\api_resources\completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\api_requestor.py:226, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     205 def request(
#     206     self,
#     207     method,
#    (...)
#     214     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     215 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     216     result = self.request_raw(
#     217         method.lower(),
#     218         url,
#    (...)
#     224         request_timeout=request_timeout,
#     225     )
# --> 226     resp, got_stream = self._interpret_response(result, stream)
#     227     return resp, got_stream, self.api_key
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\api_requestor.py:620, in APIRequestor._interpret_response(self, result, stream)
#     612     return (
#     613         self._interpret_response_line(
#     614             line, result.status_code, result.headers, stream=True
#     615         )
#     616         for line in parse_stream(result.iter_lines())
#     617     ), True
#     618 else:
#     619     return (
# --> 620         self._interpret_response_line(
#     621             result.content.decode("utf-8"),
#     622             result.status_code,
#     623             result.headers,
#     624             stream=False,
#     625         ),
#     626         False,
#     627     )
#
# File c:\Users\Alex\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\api_requestor.py:683, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     681 stream_error = stream and "error" in resp.data
#     682 if stream_error or not 200 <= rcode < 300:
# --> 683     raise self.handle_error_response(
#     684         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     685     )
#     686 return resp
#
# InvalidRequestError: This model's maximum context length is 4097 tokens, however you requested 4242 tokens (3986 in your prompt; 256 for the completion). Please reduce your prompt; or completion length.
